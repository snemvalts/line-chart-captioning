# %% [markdown]
# # Starting out

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Kool/Ülikool/'3. aasta'/Lõputöö/data.zip .
# !unzip -q data.zip
# !rm data.zip

# !cp /content/drive/MyDrive/Kool/Ülikool/'3. aasta'/Lõputöö/test_val.zip .
# !unzip -q test_val.zip
# !rm test_val.zip

# %%
# !rm -rf line-chart-captioning/
#clone repo
# !git clone https://github.com/snemvalts/line-chart-captioning
#clean out data folder and move extracted raw data to captioning
# !rm -rf line-chart-captioning/data/*
# !mv data/** line-chart-captioning/data/
# !mv test_val/validation1 line-chart-captioning/data/figureqa/
# Out:
# Cloning into 'line-chart-captioning'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 152 (delta 48), reused 119 (delta 25), pack-reused 0
# Receiving objects: 100% (152/152), 171.77 KiB | 14.31 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
import json

synthetic_json = {
  "questions": ["GREATER", "LESS", "INTERSECT"],
  "question_selection": {
    "GREATER": [
      "<Color1> is greater than <Color2>",
      "<Color1> is bigger than <Color2>",
      "<Color1> is larger than <Color2>",
    ],
    "LESS": [
      "<Color1> is less than <Color2>",
      "<Color1> is smaller than <Color2>"
    ],
    "INTERSECT": [
      "<Color1> intersects <Color2>"
    ]
  }
}

with open('line-chart-captioning/synthetic.json', 'w') as f:
  json.dump(synthetic_json, f)

# %%
# !cd line-chart-captioning && \
python3 src/synthetic/preprocess.py \
--unroll-descriptions \
--replace-subjects-locally \
--synthetic-config synthetic.json \
data/figureqa/train1
# Out:
# parsing QA...
# parsing annotations...
# processing plots...
# unrolling descriptions...
# replacing subjects...
# copying images...
# writing csv...

# %%
# !cd line-chart-captioning && \
python3 src/synthetic/preprocess.py \
--unroll-descriptions \
--replace-subjects-locally \
--synthetic-config synthetic.json \
data/figureqa/validation1
# Out:
# parsing QA...
# parsing annotations...
# processing plots...
# unrolling descriptions...
# replacing subjects...
# copying images...
# writing csv...

# %% [markdown]
# ## creating transforms & dataset

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from PIL import Image
from skimage import transform


# adapted from https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
class SyntheticImageDataset(Dataset):
  def __init__(self, csv_file, images_dir, transform=None):
    self.charts_captions = pd.read_csv(csv_file)
    self.images_dir = images_dir
    self.transform = transform

  def __len__(self):
    return len(self.charts_captions)

  def __getitem__(self, idx):
    [image_number, caption, subject_map] = self.charts_captions.iloc[idx]
    image_path = os.path.join(self.images_dir, f'{str(image_number)}.png')
    image = np.array(Image.open(image_path))
    
    sample = {'image': image, 'caption': caption, 'subject_map': subject_map }

    if self.transform:
      sample = self.transform(sample)

    return sample

# %%
class ResizeImage(object):
  def __init__(self, output_size):
    assert isinstance(output_size, (int, tuple))
    self.output_size = output_size

  def __call__(self, sample):
    resized_image = transform.resize(sample['image'], self.output_size)
    resized_original_image = transform.resize(sample['image'], (400, 600))
    return {**sample, 'image': resized_image, 'original_image': resized_original_image}

class StripImageTransparency(object):
  def __init__(self):
    pass

  def __call__(self, sample):
    stripped_transparency_image = sample['image'][:,:,:3]
    return {**sample, 'image': stripped_transparency_image}


class NormalizeImage(object):
  def __init__(self, mean, std):
    self.mean = mean
    self.std = std

  def __call__(self, sample):
    normalized_image = (sample['image'] - self.mean) / self.std
    return {**sample, 'image': normalized_image}


class ImageToTensor(object):
  def __init__(self):
    pass

  def __call__(self, sample):
    image = sample['image'].transpose((2, 0, 1))
    return {**sample, 'image': torch.tensor(image).float()}



# tokenize caption to list
# also adds caption lengths
class TokenizeCaption(object):
  def __init__(self):
    pass

  def __call__(self, sample):
    caption_split = sample['caption'].split(' ')
    return {**sample, 'caption': caption_split, 'caption_len': len(caption_split)}

# pad caption with <start> <end> <pad> captions
# assumes caption is tokenized
class PadCaption(object):
  def __init__(self, max_caption_len):
    self.max_caption_len = max_caption_len
    pass
  
  def __call__(self, sample):
    caption = sample['caption']
    caption_start_end = ['<start>'] + caption + ['<end>']
    # we added start and end
    max_caption_len = self.max_caption_len + 2
    pads = (max_caption_len - len(caption_start_end)) * ['<pad>']
    new_caption = caption_start_end + pads
    return {**sample, 'caption': new_caption, 'caption_len': len(new_caption)}

# transform caption to list of integers according to word map
# assumes caption is tokenized & padded
class TransformCaption(object):
  def __init__(self, word_map):
    self.word_map = word_map

  def __call__(self, sample):
    transformed_caption = list(map(lambda token: self.word_map[token], sample['caption']))
    return {**sample, 'caption': transformed_caption }

# turns caption to tensor
# assumes caption is transformed
class CaptionToTensor(object):
  def __init__(self):
    pass

  def __call__(self, sample):
    return {**sample, 'caption': torch.tensor(sample['caption']) }

# %%
import torch

def get_max_caption_len(csv_file):
  captions = list(pd.read_csv(csv_file)['caption'])
  sentences = [[word for word in sentence.split(' ')] for sentence in captions]
  max_caption_len = len(max(sentences, key=len))
  return max_caption_len

def get_word_map(csv_file):
  captions = list(pd.read_csv(csv_file)['caption'])
  all_words = [word for caption in captions for word in caption.split(" ")]
  unique_words = sorted(list(set(all_words)))
  # let's include the tokens that will be padded later... saves us a headache
  pad_tokens = ['<start>', '<end>', '<pad>']
  word_map = {word: i + 1 for i, word in enumerate(pad_tokens + unique_words)}
  return word_map

def get_token_map(word_map):
  return {v + 1: k for v,k in enumerate(word_map)}

def get_dataset(images_dir = None, csv_file = None):
  # parallely calculate max caption len and word map to pass it to padcaption
  # cause can't access dataset from transforms before it is defined in compose
  max_caption_len = get_max_caption_len(csv_file)
  word_map = get_word_map(csv_file)

  dataset = SyntheticImageDataset(images_dir = images_dir,
                           csv_file = csv_file,
                           transform=transforms.Compose([
                                  ResizeImage((224, 224)),
                                  StripImageTransparency(),
                                  NormalizeImage(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                  ImageToTensor(),
                                  TokenizeCaption(),
                                  PadCaption(max_caption_len=max_caption_len),
                                  TransformCaption(word_map=word_map),
                                  CaptionToTensor()
                                 ]))

  return dataset, word_map, max_caption_len + 2


train_dataset, word_map, max_caption_len = get_dataset(images_dir = 'line-chart-captioning/data/processed_synthetic/train1/images',
                      csv_file = 'line-chart-captioning/data/processed_synthetic/train1/captions.csv')


validation_dataset = SyntheticImageDataset(images_dir = 'line-chart-captioning/data/processed_synthetic/validation1/images',
                           csv_file = 'line-chart-captioning/data/processed_synthetic/validation1/captions.csv',
                           transform=transforms.Compose([
                                  ResizeImage((224, 224)),
                                  StripImageTransparency(),
                                  NormalizeImage(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                  ImageToTensor(),
                                  TokenizeCaption(),
                                  PadCaption(max_caption_len=max_caption_len),
                                  TransformCaption(word_map=word_map),
                                  CaptionToTensor()
                                 ]))


print(word_map, max_caption_len)
batch_size=32
validation_batch_size = 2

train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=True)

validation_loader = torch.utils.data.DataLoader(
        validation_dataset,
        batch_size=validation_batch_size, shuffle=True, num_workers=1, pin_memory=True)
# Out:
# {'<start>': 1, '<end>': 2, '<pad>': 3, '<A>': 4, '<B>': 5, '<C>': 6, '<D>': 7, 'bigger': 8, 'greater': 9, 'intersects': 10, 'is': 11, 'larger': 12, 'less': 13, 'smaller': 14, 'than': 15} 7

# %% [markdown]
# ## Encoder and decoder

# %%
import torchvision
from torch import nn

# Parts of model inspired by https://github.com/sgrvinod/a-PyTorch-Tutorial-to-Image-Captioning/

class Encoder(nn.Module):
  def __init__(self, encoder_output_dim = 512, trainable=False):
    super(Encoder, self).__init__()

    base_resnet = torchvision.models.resnet50(pretrained=True) 
    resnet_without_fc = nn.Sequential(*(list(base_resnet.children())[:-1]))

    # freeze weights of resnet 
    if (not trainable):
      for parameter in resnet_without_fc.parameters():
        parameter.requires_grad = False


    self.resnet = resnet_without_fc
    self.pool = nn.AdaptiveAvgPool1d(encoder_output_dim)

  
  def forward(self, x):
    x = self.resnet(x)
    x = x.squeeze().unsqueeze(1)
    x = self.pool(x).squeeze()
    return x


class FeatureAttention(nn.Module):
  def __init__(self, encoder_feature_dim, decoder_lstm_hidden_dim, attention_dim, activation='relu'):
    super(FeatureAttention, self).__init__()
    self.features_attention = nn.Linear(encoder_feature_dim, attention_dim)
    self.lstm_hidden_attention = nn.Linear(decoder_lstm_hidden_dim, attention_dim)
    self.attention = nn.Linear(attention_dim, 1)
    if (activation == 'relu'):
      self.activation = nn.ReLU()
    elif (activation == 'tanh'):
      # was in the adobe paper
      self.activation = nn.TanH()
    self.softmax = nn.Softmax(dim=1)
  
  def forward(self, encoder_features_out, decoder_lstm_hidden):
    features_attn = self.features_attention(encoder_features_out)
    decoder_attn = self.lstm_hidden_attention(decoder_lstm_hidden)
    activated = self.activation(features_attn + decoder_attn.unsqueeze(1))
    attention = self.softmax(self.attention(activated))
    attention_weighted_features = (encoder_features_out * attention).sum(dim=1)

    return attention_weighted_features


# Currently unused
class RelationAttention(nn.Module):
  def __init__(self, encoder_feature_dim, decoder_lstm_hidden_dim, attention_dim, mlp_dim, activation='relu'):
    super(RelationAttention, self).__init__()
    # with 512 encoder_feature_dim
    feature_pair_vectors_dim = 2

    self.mlp_input = nn.Linear(feature_pair_vectors_dim, mlp_dim)
    self.mlp_hidden_1 = nn.Linear(mlp_dim, mlp_dim)
    self.mlp_hidden_2 = nn.Linear(mlp_dim, mlp_dim)
    self.mlp_activation = nn.ReLU()
    self.mlp_output = nn.Linear(mlp_dim, feature_pair_vectors_dim)

    self.relations_attention = nn.Linear(feature_pair_vectors_dim, attention_dim)
    self.lstm_hidden_attention = nn.Linear(decoder_lstm_hidden_dim, attention_dim)
    self.attention = nn.Linear(attention_dim, 1)
    if (activation == 'relu'):
      self.activation = nn.ReLU()
    elif (activation == 'tanh'):
      # was in the adobe paper
      self.activation = nn.TanH()
    self.softmax = nn.Softmax(dim=1)
  


  def forward(self, encoder_features_out, decoder_lstm_hidden):
    combinations = torch.cat([torch.combinations(features).unsqueeze(0) for features in debug_tensor])

    mlp_x = self.mlp_input(combinations)
    mlp_x = self.mlp_hidden_1(mlp_x)
    mlp_x = self.mlp_hidden_2(mlp_x)
    mlp_y = self.mlp_activation(self.mlp_output(mlp_x))

    relations_attn = self.relations_attention(mlp_y)
    decoder_attn = self.lstm_hidden_attention(decoder_lstm_hidden)

    activated = self.activation(relations_attn + decoder_attn.unsqueeze(1))
    attention = self.softmax(self.attention(activated))
    attention_weighted_features = (encoder_features_out * attention).sum(dim=1)

    return attention_weighted_features


class DecoderWithAttentions(nn.Module):
  def __init__(self, embedding_dim, 
               decoder_dim, 
               vocabulary_size,
               feature_attention_dim,
               relation_attention_dim,
               encoder_dim=512, 
               mlp_dim = 128,
               dropout_p=0.5):
    super(DecoderWithAttentions, self).__init__()
    self.encoder_dim = encoder_dim
    self.attention_dim = attention_dim
    self.embedding_dim = embedding_dim
    self.decoder_dim = decoder_dim
    self.vocabulary_size = vocabulary_size

    self.features_attention = FeatureAttention(encoder_dim, decoder_dim, feature_attention_dim)
    self.relations_attention = RelationAttention(encoder_dim, decoder_dim, relation_attention_dim, mlp_dim)

    self.embedding = nn.Embedding(vocabulary_size, embedding_dim)
    self.dropout = nn.Dropout(p=dropout_p)

    # To do teacher forcing, uncomment this, embedding layer definition, and embedding concat layer
    self.decoder_lstm = nn.LSTMCell(encoder_dim+embedding_dim, decoder_dim, bias=True)
    #self.decoder_lstm = nn.LSTMCell(2068, decoder_dim, bias=True)

    self.init_h = nn.Linear(encoder_dim, decoder_dim)
    self.init_c = nn.Linear(encoder_dim, decoder_dim)
    self.forget_gate = nn.Linear(decoder_dim, encoder_dim)

    self.output = nn.Linear(decoder_dim, vocab_size)
    self.sigmoid = nn.Sigmoid()
    self.softmax = nn.Softmax()

    self.init_weights()

  def init_weights(self):
    self.embedding.weight.data.uniform_(-0.1, 0.1)
    self.output.bias.data.fill_(0)
    self.output.weight.data.uniform_(-0.1, 0.1)


  def init_hidden_state(self, encoder_out):
    mean_encoder_out = encoder_out.mean(dim=1).unsqueeze(1).repeat(1, self.encoder_dim)
    h = self.init_h(mean_encoder_out)
    c = self.init_c(mean_encoder_out)
    return h, c


  def forward(self, encoder_out, embedding_captions):
    batch_size = encoder_out.size(0)
    encoder_dim = encoder_out.size(-1)


    embeddings = self.embedding(embedding_captions)

    h, c = self.init_hidden_state(encoder_out)

    predictions = torch.zeros(batch_size, max_caption_len, vocab_size).to(device)

    # iterate until all tokens have been generated
    for t in range(max_caption_len):
      feature_attention = self.features_attention(encoder_out, h)

      context_vector = feature_attention #torch.cat((feature_attention, relations_attention))
      forget_gate = self.sigmoid(self.forget_gate(h))

      context_vector = forget_gate * context_vector


      lstm_input = torch.cat([embeddings[:, t, :], context_vector], dim=1)
      #lstm_input = torch.cat([predictions[:, t - 1, :], context_vector], dim=1)

      h, c = self.decoder_lstm(lstm_input, (h, c))
        
      predicted_tokens = self.softmax(self.output(self.dropout(h)))
      predictions[:, t, :] = predicted_tokens

    return predictions

# %%
# from https://github.com/sgrvinod/a-PyTorch-Tutorial-to-Image-Captioning/
def accuracy(scores, targets, k):
    """
    Computes top-k accuracy, from predicted and true labels.
    :param scores: scores from the model
    :param targets: true labels
    :param k: k in top-k accuracy
    :return: top-k accuracy
    """
    scores = scores.view(1, -1, *(scores.size()[2:])).squeeze()
    targets = targets.view(1, -1, *(targets.size()[2:])).squeeze()

    batch_size = targets.size(0)
    _, ind = scores.topk(k, 1, True, True)
    correct = ind.eq(targets.view(-1, 1).expand_as(ind))
    correct_total = correct.view(-1).float().sum()  # 0D tensor
    return correct_total.item() * (100.0 / batch_size)

# %%
from torch.nn.utils.rnn import pack_padded_sequence
from nltk.translate.bleu_score import corpus_bleu
import random
import gc

torch.cuda.empty_cache()
gc.collect()

def get_caption_from_transformed(prediction, token_map):
  return [[token_map[token] if token in token_map else '?' for token in tokens] for tokens in prediction]

def strip_start_end_pad(prediction):
  return [list(filter(lambda token: token != '<start>' and token != '<end>' and token != '<pad>', tokens)) for tokens in prediction]

def get_ground_truth_captions(ground_truth_transformed_captions, token_map):
  ground_truth_captions_padded = get_caption_from_transformed(ground_truth_transformed_captions, token_map)

  ground_truth_captions = []

  for caption in ground_truth_captions_padded:
    new_caption = list(filter(lambda x : x != '<start>' and x != '<end>' and x != '<pad>', caption))
    ground_truth_captions.append(new_caption)

  return ground_truth_captions


def train_epoch(encoder_dim, decoder_dim, attention_dim, embed_dim, vocab_size, iter_cap=300):
  global min_loss
  iter_without_improvement = 0

  for i, batch in enumerate(train_loader):
    imgs = batch['image'].to(device)
    target_caps = batch['caption'].to(device)

    imgs = encoder(imgs)
    prediction_scores = decoder(imgs, target_caps)

    # Calculate loss
    loss = criterion(prediction_scores.permute(0,2,1), target_caps)

    decoder_optimizer.zero_grad()
    loss.backward()
    decoder_optimizer.step()

    #encoder_optimizer.zero_grad()
    #encoder_optimizer.step()

    loss_score = loss.cpu().detach().numpy()

    if (loss_score <= min_loss):
      min_loss = loss_score
      iter_without_improvement = 0
    else:
      iter_without_improvement += 1

    predicted_captions = torch.argmax(prediction_scores, dim=2).cpu().numpy()

    hypotheses = strip_start_end_pad(get_caption_from_transformed(predicted_captions, token_map))
    ground_truth_transformed = batch['caption'].cpu().numpy()
    ground_truth_captions = get_ground_truth_captions(ground_truth_transformed, token_map)

    ground_truth_captions_bleu = [[caption] for caption in ground_truth_captions]
    bleu_score = corpus_bleu(ground_truth_captions_bleu, hypotheses)
    accuracy_score = accuracy(prediction_scores, target_caps, 2)

    print(f"Batch #{i}/{len(train_loader)}: BLEU is {bleu_score:.2f}, loss is {loss_score:.3f}, top-2 accuracy is {accuracy_score:.1f}%")
    rand_i = random.randint(0, batch_size - 1)

    try:
      print("random prediction: ", hypotheses[rand_i])
      print("and the corresponding caption: ", ground_truth_captions[rand_i])
    except IndexError:
      pass

    #if (iter_without_improvement >= iter_cap):
    #  print(f"{iter_cap} iterations without improvement. stopping")
    #  break




encoder_dim = 2048
decoder_dim = 1024
attention_dim = 1024
embed_dim = 256
vocab_size = 20
decoder_lr = 3e-5
#encoder_lr = 1e-4

epochs = 5

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

encoder = Encoder(encoder_output_dim=encoder_dim, trainable=True).to(device)
#encoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, encoder.parameters()),
#                                             lr=encoder_lr)

decoder = DecoderWithAttentions(embed_dim, 
                                decoder_dim, 
                                vocab_size, 
                                attention_dim, 
                                attention_dim, 
                                encoder_dim=encoder_dim
                                ).to(device)
decoder_optimizer = torch.optim.Adam(params=filter(lambda p: p.requires_grad, decoder.parameters()),
                                             lr=decoder_lr)

criterion = nn.CrossEntropyLoss().to(device)
token_map = get_token_map(word_map)

min_loss = float('inf')
iter_without_improvement = 0

decoder.train()

for epoch in range(epochs):
  print(f"Epoch {epoch + 1} of {epochs}")
  train_epoch(encoder_dim, decoder_dim, attention_dim, embed_dim, vocab_size)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# Epoch 1 of 5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:171: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Batch #0/1433: BLEU is 0.36, loss is 2.993, top-2 accuracy is 11.2%
# random prediction:  ['larger', 'than', 'than']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #1/1433: BLEU is 0.01, loss is 2.980, top-2 accuracy is 27.2%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #2/1433: BLEU is 0.00, loss is 2.965, top-2 accuracy is 31.7%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #3/1433: BLEU is 0.00, loss is 2.941, top-2 accuracy is 37.1%
# random prediction:  ['<B>']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #4/1433: BLEU is 0.00, loss is 2.916, top-2 accuracy is 35.7%
# random prediction:  ['<B>']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #5/1433: BLEU is 0.00, loss is 2.889, top-2 accuracy is 36.2%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #6/1433: BLEU is 0.00, loss is 2.872, top-2 accuracy is 34.4%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #7/1433: BLEU is 0.00, loss is 2.849, top-2 accuracy is 42.9%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #8/1433: BLEU is 0.00, loss is 2.842, top-2 accuracy is 36.2%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #9/1433: BLEU is 0.00, loss is 2.829, top-2 accuracy is 38.4%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #10/1433: BLEU is 0.00, loss is 2.823, top-2 accuracy is 38.8%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #11/1433: BLEU is 0.00, loss is 2.817, top-2 accuracy is 36.6%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #12/1433: BLEU is 0.00, loss is 2.802, top-2 accuracy is 39.7%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #13/1433: BLEU is 0.00, loss is 2.803, top-2 accuracy is 36.6%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #14/1433: BLEU is 0.00, loss is 2.796, top-2 accuracy is 35.7%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #15/1433: BLEU is 0.00, loss is 2.783, top-2 accuracy is 41.1%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #16/1433: BLEU is 0.00, loss is 2.786, top-2 accuracy is 33.0%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #17/1433: BLEU is 0.00, loss is 2.782, top-2 accuracy is 34.8%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #18/1433: BLEU is 0.00, loss is 2.776, top-2 accuracy is 42.0%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #19/1433: BLEU is 0.00, loss is 2.780, top-2 accuracy is 37.5%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #20/1433: BLEU is 0.00, loss is 2.779, top-2 accuracy is 33.0%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #21/1433: BLEU is 0.00, loss is 2.774, top-2 accuracy is 39.3%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #22/1433: BLEU is 0.00, loss is 2.772, top-2 accuracy is 37.9%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #23/1433: BLEU is 0.00, loss is 2.771, top-2 accuracy is 40.2%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #24/1433: BLEU is 0.00, loss is 2.770, top-2 accuracy is 38.8%
# random prediction:  []
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #25/1433: BLEU is 0.00, loss is 2.763, top-2 accuracy is 44.2%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #26/1433: BLEU is 0.00, loss is 2.756, top-2 accuracy is 42.0%
# random prediction:  []
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #27/1433: BLEU is 0.00, loss is 2.748, top-2 accuracy is 50.9%
# random prediction:  ['<B>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #28/1433: BLEU is 0.01, loss is 2.742, top-2 accuracy is 48.7%
# random prediction:  ['<B>']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #29/1433: BLEU is 0.04, loss is 2.737, top-2 accuracy is 47.3%
# random prediction:  ['<B>']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #30/1433: BLEU is 0.06, loss is 2.734, top-2 accuracy is 52.2%
# random prediction:  ['<B>']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #31/1433: BLEU is 0.17, loss is 2.718, top-2 accuracy is 49.6%
# random prediction:  ['<B>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #32/1433: BLEU is 0.18, loss is 2.723, top-2 accuracy is 50.0%
# random prediction:  ['<B>']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #33/1433: BLEU is 0.30, loss is 2.710, top-2 accuracy is 51.3%
# random prediction:  ['<B>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #34/1433: BLEU is 0.31, loss is 2.716, top-2 accuracy is 50.9%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #35/1433: BLEU is 0.41, loss is 2.714, top-2 accuracy is 50.4%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #36/1433: BLEU is 0.51, loss is 2.708, top-2 accuracy is 49.1%
# random prediction:  ['<B>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #37/1433: BLEU is 0.48, loss is 2.712, top-2 accuracy is 50.9%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #38/1433: BLEU is 0.48, loss is 2.703, top-2 accuracy is 51.8%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #39/1433: BLEU is 0.45, loss is 2.719, top-2 accuracy is 51.3%
# random prediction:  ['<B>', '<B>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #40/1433: BLEU is 0.51, loss is 2.701, top-2 accuracy is 51.3%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #41/1433: BLEU is 0.52, loss is 2.705, top-2 accuracy is 50.0%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #42/1433: BLEU is 0.56, loss is 2.703, top-2 accuracy is 51.3%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #43/1433: BLEU is 0.48, loss is 2.700, top-2 accuracy is 53.1%
# random prediction:  ['<A>', '<A>', '<B>']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #44/1433: BLEU is 0.52, loss is 2.706, top-2 accuracy is 52.7%
# random prediction:  ['<B>', '<A>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #45/1433: BLEU is 0.54, loss is 2.704, top-2 accuracy is 51.3%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #46/1433: BLEU is 0.50, loss is 2.702, top-2 accuracy is 52.2%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #47/1433: BLEU is 0.49, loss is 2.697, top-2 accuracy is 53.1%
# random prediction:  ['<A>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #48/1433: BLEU is 0.55, loss is 2.697, top-2 accuracy is 54.0%
# random prediction:  ['<A>', '<A>', '<A>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #49/1433: BLEU is 0.49, loss is 2.690, top-2 accuracy is 53.6%
# random prediction:  ['<A>', '<B>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #50/1433: BLEU is 0.48, loss is 2.698, top-2 accuracy is 54.5%
# random prediction:  ['<A>', '<B>', '<B>']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #51/1433: BLEU is 0.48, loss is 2.698, top-2 accuracy is 50.4%
# random prediction:  ['<B>', '<B>']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #52/1433: BLEU is 0.41, loss is 2.702, top-2 accuracy is 50.9%
# random prediction:  ['<A>', '<A>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #53/1433: BLEU is 0.47, loss is 2.696, top-2 accuracy is 53.1%
# random prediction:  ['<A>', '<A>', '<A>']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #54/1433: BLEU is 0.44, loss is 2.698, top-2 accuracy is 52.7%
# random prediction:  ['<A>', '<A>', '<A>']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #55/1433: BLEU is 0.49, loss is 2.692, top-2 accuracy is 55.8%
# random prediction:  ['<A>', '<A>', '<B>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #56/1433: BLEU is 0.44, loss is 2.695, top-2 accuracy is 52.7%
# random prediction:  ['<A>', '<A>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #57/1433: BLEU is 0.47, loss is 2.691, top-2 accuracy is 52.7%
# random prediction:  ['<A>', '<A>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #58/1433: BLEU is 0.46, loss is 2.698, top-2 accuracy is 52.7%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #59/1433: BLEU is 0.43, loss is 2.697, top-2 accuracy is 54.0%
# random prediction:  ['<B>', '<A>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #60/1433: BLEU is 0.50, loss is 2.688, top-2 accuracy is 54.0%
# random prediction:  ['<A>', '<B>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #61/1433: BLEU is 0.46, loss is 2.695, top-2 accuracy is 53.6%
# random prediction:  ['<B>', '<B>']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #62/1433: BLEU is 0.48, loss is 2.691, top-2 accuracy is 54.9%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #63/1433: BLEU is 0.55, loss is 2.683, top-2 accuracy is 56.2%
# random prediction:  ['<B>', '<A>', '<A>']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #64/1433: BLEU is 0.54, loss is 2.689, top-2 accuracy is 55.8%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #65/1433: BLEU is 0.50, loss is 2.693, top-2 accuracy is 52.2%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #66/1433: BLEU is 0.53, loss is 2.689, top-2 accuracy is 54.0%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #67/1433: BLEU is 0.54, loss is 2.689, top-2 accuracy is 53.1%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #68/1433: BLEU is 0.52, loss is 2.681, top-2 accuracy is 55.8%
# random prediction:  ['<B>', '<B>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #69/1433: BLEU is 0.51, loss is 2.686, top-2 accuracy is 55.4%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #70/1433: BLEU is 0.53, loss is 2.689, top-2 accuracy is 53.6%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #71/1433: BLEU is 0.48, loss is 2.693, top-2 accuracy is 53.6%
# random prediction:  ['<B>', '<B>']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #72/1433: BLEU is 0.50, loss is 2.680, top-2 accuracy is 55.8%
# random prediction:  ['<A>', '<A>', '<B>']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #73/1433: BLEU is 0.49, loss is 2.681, top-2 accuracy is 53.1%
# random prediction:  ['<A>', '<B>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #74/1433: BLEU is 0.43, loss is 2.692, top-2 accuracy is 54.5%
# random prediction:  ['<B>', '<B>', '<A>']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #75/1433: BLEU is 0.47, loss is 2.690, top-2 accuracy is 54.0%
# random prediction:  ['<A>', '<A>', '<B>']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Batch #76/1433: BLEU is 0.15, loss is 2.682, top-2 accuracy is 50.9%
# random prediction:  ['<A>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #77/1433: BLEU is 0.47, loss is 2.687, top-2 accuracy is 53.6%
# random prediction:  ['<B>', '<A>', '<A>']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #78/1433: BLEU is 0.42, loss is 2.685, top-2 accuracy is 53.1%
# random prediction:  ['<A>', '<A>', '<A>']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #79/1433: BLEU is 0.17, loss is 2.680, top-2 accuracy is 54.5%
# random prediction:  ['<A>', '<A>', '<A>']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #80/1433: BLEU is 0.48, loss is 2.677, top-2 accuracy is 53.6%
# random prediction:  ['<B>', '<B>']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #81/1433: BLEU is 0.30, loss is 2.679, top-2 accuracy is 54.5%
# random prediction:  ['<B>', '<A>', '<A>']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #82/1433: BLEU is 0.26, loss is 2.684, top-2 accuracy is 52.7%
# random prediction:  ['<A>', '<B>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #83/1433: BLEU is 0.36, loss is 2.669, top-2 accuracy is 55.4%
# random prediction:  ['<A>', '<B>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #84/1433: BLEU is 0.40, loss is 2.658, top-2 accuracy is 55.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #85/1433: BLEU is 0.39, loss is 2.670, top-2 accuracy is 55.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #86/1433: BLEU is 0.38, loss is 2.644, top-2 accuracy is 54.5%
# random prediction:  ['is', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #87/1433: BLEU is 0.35, loss is 2.637, top-2 accuracy is 53.1%
# random prediction:  ['is', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #88/1433: BLEU is 0.35, loss is 2.646, top-2 accuracy is 51.3%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #89/1433: BLEU is 0.30, loss is 2.638, top-2 accuracy is 53.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #90/1433: BLEU is 0.35, loss is 2.648, top-2 accuracy is 52.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #91/1433: BLEU is 0.35, loss is 2.621, top-2 accuracy is 54.0%
# random prediction:  ['is', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #92/1433: BLEU is 0.37, loss is 2.644, top-2 accuracy is 54.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #93/1433: BLEU is 0.38, loss is 2.620, top-2 accuracy is 55.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #94/1433: BLEU is 0.35, loss is 2.636, top-2 accuracy is 54.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #95/1433: BLEU is 0.31, loss is 2.622, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #96/1433: BLEU is 0.31, loss is 2.607, top-2 accuracy is 57.1%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #97/1433: BLEU is 0.31, loss is 2.615, top-2 accuracy is 54.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #98/1433: BLEU is 0.33, loss is 2.622, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #99/1433: BLEU is 0.33, loss is 2.603, top-2 accuracy is 55.4%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #100/1433: BLEU is 0.33, loss is 2.617, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #101/1433: BLEU is 0.35, loss is 2.620, top-2 accuracy is 54.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #102/1433: BLEU is 0.37, loss is 2.643, top-2 accuracy is 53.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #103/1433: BLEU is 0.39, loss is 2.590, top-2 accuracy is 55.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #104/1433: BLEU is 0.39, loss is 2.602, top-2 accuracy is 55.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #105/1433: BLEU is 0.39, loss is 2.623, top-2 accuracy is 51.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #106/1433: BLEU is 0.38, loss is 2.606, top-2 accuracy is 53.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #107/1433: BLEU is 0.37, loss is 2.588, top-2 accuracy is 55.4%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #108/1433: BLEU is 0.31, loss is 2.602, top-2 accuracy is 53.6%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #109/1433: BLEU is 0.37, loss is 2.604, top-2 accuracy is 55.4%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #110/1433: BLEU is 0.36, loss is 2.586, top-2 accuracy is 54.9%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #111/1433: BLEU is 0.38, loss is 2.612, top-2 accuracy is 54.5%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #112/1433: BLEU is 0.37, loss is 2.612, top-2 accuracy is 54.9%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #113/1433: BLEU is 0.37, loss is 2.596, top-2 accuracy is 54.9%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #114/1433: BLEU is 0.36, loss is 2.594, top-2 accuracy is 54.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #115/1433: BLEU is 0.29, loss is 2.591, top-2 accuracy is 55.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #116/1433: BLEU is 0.34, loss is 2.594, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #117/1433: BLEU is 0.34, loss is 2.592, top-2 accuracy is 55.4%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #118/1433: BLEU is 0.33, loss is 2.590, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #119/1433: BLEU is 0.34, loss is 2.577, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #120/1433: BLEU is 0.32, loss is 2.583, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #121/1433: BLEU is 0.32, loss is 2.611, top-2 accuracy is 54.5%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #122/1433: BLEU is 0.33, loss is 2.620, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #123/1433: BLEU is 0.37, loss is 2.604, top-2 accuracy is 55.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #124/1433: BLEU is 0.34, loss is 2.584, top-2 accuracy is 56.2%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #125/1433: BLEU is 0.36, loss is 2.584, top-2 accuracy is 54.5%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #126/1433: BLEU is 0.37, loss is 2.599, top-2 accuracy is 55.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #127/1433: BLEU is 0.36, loss is 2.602, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #128/1433: BLEU is 0.35, loss is 2.581, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #129/1433: BLEU is 0.35, loss is 2.583, top-2 accuracy is 55.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #130/1433: BLEU is 0.30, loss is 2.586, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #131/1433: BLEU is 0.33, loss is 2.586, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #132/1433: BLEU is 0.37, loss is 2.618, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #133/1433: BLEU is 0.33, loss is 2.578, top-2 accuracy is 56.2%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #134/1433: BLEU is 0.34, loss is 2.582, top-2 accuracy is 56.2%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #135/1433: BLEU is 0.34, loss is 2.585, top-2 accuracy is 56.2%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #136/1433: BLEU is 0.32, loss is 2.573, top-2 accuracy is 54.5%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #137/1433: BLEU is 0.36, loss is 2.589, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #138/1433: BLEU is 0.36, loss is 2.604, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #139/1433: BLEU is 0.38, loss is 2.593, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #140/1433: BLEU is 0.34, loss is 2.590, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #141/1433: BLEU is 0.36, loss is 2.596, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #142/1433: BLEU is 0.37, loss is 2.596, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #143/1433: BLEU is 0.33, loss is 2.575, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #144/1433: BLEU is 0.34, loss is 2.590, top-2 accuracy is 57.1%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #145/1433: BLEU is 0.35, loss is 2.581, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #146/1433: BLEU is 0.32, loss is 2.601, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #147/1433: BLEU is 0.32, loss is 2.610, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #148/1433: BLEU is 0.34, loss is 2.561, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #149/1433: BLEU is 0.37, loss is 2.593, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #150/1433: BLEU is 0.36, loss is 2.608, top-2 accuracy is 55.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #151/1433: BLEU is 0.37, loss is 2.594, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #152/1433: BLEU is 0.35, loss is 2.590, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #153/1433: BLEU is 0.35, loss is 2.574, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #154/1433: BLEU is 0.37, loss is 2.589, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #155/1433: BLEU is 0.35, loss is 2.579, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #156/1433: BLEU is 0.36, loss is 2.574, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #157/1433: BLEU is 0.32, loss is 2.564, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #158/1433: BLEU is 0.39, loss is 2.614, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #159/1433: BLEU is 0.35, loss is 2.582, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #160/1433: BLEU is 0.34, loss is 2.565, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #161/1433: BLEU is 0.35, loss is 2.600, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #162/1433: BLEU is 0.35, loss is 2.582, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<C>', 'intersects', '<B>']
# Batch #163/1433: BLEU is 0.35, loss is 2.576, top-2 accuracy is 55.8%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #164/1433: BLEU is 0.37, loss is 2.566, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #165/1433: BLEU is 0.34, loss is 2.568, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #166/1433: BLEU is 0.37, loss is 2.579, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #167/1433: BLEU is 0.36, loss is 2.599, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #168/1433: BLEU is 0.35, loss is 2.559, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #169/1433: BLEU is 0.35, loss is 2.565, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #170/1433: BLEU is 0.38, loss is 2.573, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #171/1433: BLEU is 0.36, loss is 2.584, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #172/1433: BLEU is 0.34, loss is 2.586, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #173/1433: BLEU is 0.34, loss is 2.559, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #174/1433: BLEU is 0.35, loss is 2.562, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #175/1433: BLEU is 0.31, loss is 2.554, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #176/1433: BLEU is 0.36, loss is 2.590, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #177/1433: BLEU is 0.34, loss is 2.584, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #178/1433: BLEU is 0.35, loss is 2.577, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #179/1433: BLEU is 0.35, loss is 2.590, top-2 accuracy is 55.4%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #180/1433: BLEU is 0.35, loss is 2.575, top-2 accuracy is 56.2%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #181/1433: BLEU is 0.34, loss is 2.576, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #182/1433: BLEU is 0.36, loss is 2.585, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #183/1433: BLEU is 0.36, loss is 2.564, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #184/1433: BLEU is 0.36, loss is 2.566, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #185/1433: BLEU is 0.37, loss is 2.581, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #186/1433: BLEU is 0.36, loss is 2.563, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #187/1433: BLEU is 0.35, loss is 2.564, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #188/1433: BLEU is 0.34, loss is 2.561, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #189/1433: BLEU is 0.33, loss is 2.557, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #190/1433: BLEU is 0.37, loss is 2.582, top-2 accuracy is 56.2%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #191/1433: BLEU is 0.36, loss is 2.566, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #192/1433: BLEU is 0.35, loss is 2.564, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #193/1433: BLEU is 0.35, loss is 2.567, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #194/1433: BLEU is 0.34, loss is 2.561, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<C>', 'intersects', '<A>']
# Batch #195/1433: BLEU is 0.33, loss is 2.569, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #196/1433: BLEU is 0.34, loss is 2.567, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<C>', 'is', 'bigger', 'than', '<A>']
# Batch #197/1433: BLEU is 0.35, loss is 2.571, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #198/1433: BLEU is 0.36, loss is 2.584, top-2 accuracy is 56.2%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #199/1433: BLEU is 0.35, loss is 2.576, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #200/1433: BLEU is 0.34, loss is 2.568, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #201/1433: BLEU is 0.34, loss is 2.551, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #202/1433: BLEU is 0.37, loss is 2.575, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #203/1433: BLEU is 0.36, loss is 2.582, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #204/1433: BLEU is 0.35, loss is 2.562, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #205/1433: BLEU is 0.35, loss is 2.558, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #206/1433: BLEU is 0.37, loss is 2.583, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #207/1433: BLEU is 0.34, loss is 2.556, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #208/1433: BLEU is 0.37, loss is 2.561, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #209/1433: BLEU is 0.36, loss is 2.558, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #210/1433: BLEU is 0.35, loss is 2.566, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #211/1433: BLEU is 0.36, loss is 2.571, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #212/1433: BLEU is 0.34, loss is 2.566, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #213/1433: BLEU is 0.34, loss is 2.548, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #214/1433: BLEU is 0.33, loss is 2.571, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #215/1433: BLEU is 0.32, loss is 2.566, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #216/1433: BLEU is 0.36, loss is 2.564, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #217/1433: BLEU is 0.33, loss is 2.551, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #218/1433: BLEU is 0.36, loss is 2.557, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #219/1433: BLEU is 0.32, loss is 2.551, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #220/1433: BLEU is 0.36, loss is 2.550, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #221/1433: BLEU is 0.36, loss is 2.570, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #222/1433: BLEU is 0.32, loss is 2.532, top-2 accuracy is 55.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #223/1433: BLEU is 0.37, loss is 2.559, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #224/1433: BLEU is 0.34, loss is 2.570, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #225/1433: BLEU is 0.33, loss is 2.556, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #226/1433: BLEU is 0.34, loss is 2.561, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #227/1433: BLEU is 0.34, loss is 2.532, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #228/1433: BLEU is 0.36, loss is 2.565, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #229/1433: BLEU is 0.36, loss is 2.586, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #230/1433: BLEU is 0.37, loss is 2.566, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #231/1433: BLEU is 0.36, loss is 2.562, top-2 accuracy is 56.2%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #232/1433: BLEU is 0.37, loss is 2.554, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #233/1433: BLEU is 0.36, loss is 2.565, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #234/1433: BLEU is 0.32, loss is 2.566, top-2 accuracy is 56.7%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #235/1433: BLEU is 0.34, loss is 2.561, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #236/1433: BLEU is 0.36, loss is 2.547, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #237/1433: BLEU is 0.34, loss is 2.552, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #238/1433: BLEU is 0.37, loss is 2.562, top-2 accuracy is 60.3%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #239/1433: BLEU is 0.36, loss is 2.534, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #240/1433: BLEU is 0.36, loss is 2.563, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #241/1433: BLEU is 0.32, loss is 2.562, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #242/1433: BLEU is 0.31, loss is 2.543, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #243/1433: BLEU is 0.36, loss is 2.570, top-2 accuracy is 59.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #244/1433: BLEU is 0.33, loss is 2.555, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #245/1433: BLEU is 0.38, loss is 2.557, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #246/1433: BLEU is 0.33, loss is 2.557, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #247/1433: BLEU is 0.36, loss is 2.574, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #248/1433: BLEU is 0.38, loss is 2.553, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #249/1433: BLEU is 0.28, loss is 2.544, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #250/1433: BLEU is 0.31, loss is 2.548, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #251/1433: BLEU is 0.32, loss is 2.551, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #252/1433: BLEU is 0.38, loss is 2.548, top-2 accuracy is 57.1%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #253/1433: BLEU is 0.37, loss is 2.569, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #254/1433: BLEU is 0.36, loss is 2.580, top-2 accuracy is 59.8%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #255/1433: BLEU is 0.36, loss is 2.569, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #256/1433: BLEU is 0.39, loss is 2.552, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #257/1433: BLEU is 0.37, loss is 2.581, top-2 accuracy is 56.2%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #258/1433: BLEU is 0.36, loss is 2.556, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #259/1433: BLEU is 0.39, loss is 2.573, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #260/1433: BLEU is 0.37, loss is 2.573, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #261/1433: BLEU is 0.34, loss is 2.574, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #262/1433: BLEU is 0.36, loss is 2.551, top-2 accuracy is 57.1%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #263/1433: BLEU is 0.34, loss is 2.559, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #264/1433: BLEU is 0.29, loss is 2.547, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #265/1433: BLEU is 0.35, loss is 2.554, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #266/1433: BLEU is 0.35, loss is 2.542, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #267/1433: BLEU is 0.36, loss is 2.547, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #268/1433: BLEU is 0.33, loss is 2.546, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #269/1433: BLEU is 0.32, loss is 2.573, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<C>', 'is', 'greater', 'than', '<A>']
# Batch #270/1433: BLEU is 0.34, loss is 2.560, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# ...
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #355/1433: BLEU is 0.34, loss is 2.560, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #356/1433: BLEU is 0.31, loss is 2.560, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #357/1433: BLEU is 0.34, loss is 2.538, top-2 accuracy is 59.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #358/1433: BLEU is 0.32, loss is 2.543, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #359/1433: BLEU is 0.34, loss is 2.547, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #360/1433: BLEU is 0.34, loss is 2.582, top-2 accuracy is 60.7%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #361/1433: BLEU is 0.30, loss is 2.556, top-2 accuracy is 60.3%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #362/1433: BLEU is 0.36, loss is 2.560, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #363/1433: BLEU is 0.34, loss is 2.556, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #364/1433: BLEU is 0.37, loss is 2.543, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #365/1433: BLEU is 0.36, loss is 2.560, top-2 accuracy is 59.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #366/1433: BLEU is 0.30, loss is 2.542, top-2 accuracy is 57.1%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #367/1433: BLEU is 0.34, loss is 2.547, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #368/1433: BLEU is 0.37, loss is 2.538, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #369/1433: BLEU is 0.36, loss is 2.560, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #370/1433: BLEU is 0.36, loss is 2.542, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #371/1433: BLEU is 0.36, loss is 2.551, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #372/1433: BLEU is 0.36, loss is 2.542, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #373/1433: BLEU is 0.36, loss is 2.529, top-2 accuracy is 57.6%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #374/1433: BLEU is 0.35, loss is 2.569, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #375/1433: BLEU is 0.29, loss is 2.533, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #376/1433: BLEU is 0.38, loss is 2.564, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #377/1433: BLEU is 0.33, loss is 2.559, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #378/1433: BLEU is 0.35, loss is 2.565, top-2 accuracy is 60.3%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #379/1433: BLEU is 0.37, loss is 2.564, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #380/1433: BLEU is 0.35, loss is 2.538, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #381/1433: BLEU is 0.35, loss is 2.528, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #382/1433: BLEU is 0.34, loss is 2.564, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #383/1433: BLEU is 0.31, loss is 2.547, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #384/1433: BLEU is 0.38, loss is 2.560, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #385/1433: BLEU is 0.37, loss is 2.560, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #386/1433: BLEU is 0.34, loss is 2.555, top-2 accuracy is 60.7%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #387/1433: BLEU is 0.37, loss is 2.551, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #388/1433: BLEU is 0.34, loss is 2.542, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #389/1433: BLEU is 0.36, loss is 2.533, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #390/1433: BLEU is 0.33, loss is 2.551, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #391/1433: BLEU is 0.37, loss is 2.568, top-2 accuracy is 60.7%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #392/1433: BLEU is 0.36, loss is 2.559, top-2 accuracy is 59.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #393/1433: BLEU is 0.34, loss is 2.546, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #394/1433: BLEU is 0.36, loss is 2.546, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #395/1433: BLEU is 0.34, loss is 2.546, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #396/1433: BLEU is 0.32, loss is 2.555, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #397/1433: BLEU is 0.36, loss is 2.555, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #398/1433: BLEU is 0.31, loss is 2.569, top-2 accuracy is 61.2%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #399/1433: BLEU is 0.34, loss is 2.560, top-2 accuracy is 59.8%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #400/1433: BLEU is 0.37, loss is 2.551, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #401/1433: BLEU is 0.37, loss is 2.546, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #402/1433: BLEU is 0.34, loss is 2.541, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #403/1433: BLEU is 0.35, loss is 2.555, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #404/1433: BLEU is 0.33, loss is 2.550, top-2 accuracy is 58.0%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<C>', 'is', 'greater', 'than', '<B>']
# Batch #405/1433: BLEU is 0.36, loss is 2.550, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #406/1433: BLEU is 0.31, loss is 2.524, top-2 accuracy is 57.1%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #407/1433: BLEU is 0.35, loss is 2.564, top-2 accuracy is 59.8%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'intersects', '<B>']
# Batch #408/1433: BLEU is 0.38, loss is 2.551, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #409/1433: BLEU is 0.30, loss is 2.546, top-2 accuracy is 58.5%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #410/1433: BLEU is 0.35, loss is 2.537, top-2 accuracy is 57.6%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #411/1433: BLEU is 0.37, loss is 2.555, top-2 accuracy is 58.9%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'smaller', 'than', '<B>']
# Batch #412/1433: BLEU is 0.33, loss is 2.533, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #413/1433: BLEU is 0.34, loss is 2.545, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'larger', 'than', '<A>']
# Batch #414/1433: BLEU is 0.38, loss is 2.568, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #415/1433: BLEU is 0.32, loss is 2.555, top-2 accuracy is 59.4%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'greater', 'than', '<B>']
# Batch #416/1433: BLEU is 0.32, loss is 2.559, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #417/1433: BLEU is 0.35, loss is 2.542, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #418/1433: BLEU is 0.34, loss is 2.568, top-2 accuracy is 61.2%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #419/1433: BLEU is 0.34, loss is 2.559, top-2 accuracy is 59.4%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #420/1433: BLEU is 0.35, loss is 2.560, top-2 accuracy is 61.2%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# Batch #421/1433: BLEU is 0.34, loss is 2.546, top-2 accuracy is 60.3%
# random prediction:  ['<A>', 'is']
# and the corresponding caption:  ['<A>', 'is', 'larger', 'than', '<B>']
# Batch #422/1433: BLEU is 0.33, loss is 2.546, top-2 accuracy is 58.0%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #423/1433: BLEU is 0.32, loss is 2.550, top-2 accuracy is 58.5%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'less', 'than', '<B>']
# Batch #424/1433: BLEU is 0.36, loss is 2.546, top-2 accuracy is 60.3%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'greater', 'than', '<A>']
# Batch #425/1433: BLEU is 0.34, loss is 2.573, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'intersects', '<A>']
# Batch #426/1433: BLEU is 0.36, loss is 2.537, top-2 accuracy is 58.9%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'less', 'than', '<A>']
# Batch #427/1433: BLEU is 0.40, loss is 2.555, top-2 accuracy is 59.8%
# random prediction:  ['<A>', 'is', 'is']
# and the corresponding caption:  ['<A>', 'is', 'bigger', 'than', '<B>']
# Batch #428/1433: BLEU is 0.37, loss is 2.577, top-2 accuracy is 59.8%
# random prediction:  ['<B>', 'is']
# and the corresponding caption:  ['<B>', 'is', 'smaller', 'than', '<A>']
# Batch #429/1433: BLEU is 0.35, loss is 2.572, top-2 accuracy is 56.7%
# random prediction:  ['<B>', 'is', 'is']
# and the corresponding caption:  ['<B>', 'is', 'bigger', 'than', '<A>']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-223503d65863> in <module>()
#     116 for epoch in range(epochs):
#     117   print(f"Epoch {epoch + 1} of {epochs}")
# --> 118   train_epoch(encoder_dim, decoder_dim, attention_dim, embed_dim, vocab_size)
#
# <ipython-input-12-223503d65863> in train_epoch(encoder_dim, decoder_dim, attention_dim, embed_dim, vocab_size, iter_cap)
#      29   iter_without_improvement = 0
#      30
# ---> 31   for i, batch in enumerate(train_loader):
#      32     imgs = batch['image'].to(device)
#      33     target_caps = batch['caption'].to(device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1180
#    1181             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1182             idx, data = self._get_data()
#    1183             self._tasks_outstanding -= 1
#    1184             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1136         elif self._pin_memory:
#    1137             while self._pin_memory_thread.is_alive():
# -> 1138                 success, data = self._try_get_data()
#    1139                 if success:
#    1140                     return data
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     984         #   (bool: whether successfully get data, any: data if successful else None)
#     985         try:
# --> 986             data = self._data_queue.get(timeout=timeout)
#     987             return (True, data)
#     988         except Exception as e:
#
# /usr/lib/python3.7/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /usr/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import gc
import matplotlib.pyplot as plt


torch.cuda.empty_cache()
gc.collect()


previous_captions = torch.ones(validation_batch_size, max_caption_len) * 10
previous_captions = previous_captions.type(torch.LongTensor).to(device)

def infer_next_validation_image():
  global previous_captions
  with torch.no_grad():
    batch = next(iter(validation_loader))
    imgs = batch['image'].to(device)
    encoded_imgs = encoder(imgs)

    prediction_scores = decoder(encoded_imgs, previous_captions)

    predicted_captions = torch.argmax(prediction_scores, dim=2).cpu().numpy()
    previous_captions = predicted_captions

    hypotheses = get_caption_from_transformed(predicted_captions, token_map)
    ground_truth_transformed = batch['caption'].cpu().numpy()
    ground_truth_captions = get_ground_truth_captions(ground_truth_transformed, token_map)
    plt.figure(figsize = (10, 10))
    plt.imshow(batch['original_image'][0])


    print(hypotheses[0])

infer_next_validation_image()

# %% [markdown]
# ## saving logic

# %%
import datetime
date_str = datetime.datetime.now().replace(microsecond=0).isoformat()

lstm_decoder_model_name = f'lstm_decoder_{date_str}_state.pth'

torch.save(decoder.state_dict(), f"/content/drive/MyDrive/Kool/Ülikool/3. aasta/Lõputöö/{lstm_decoder_model_name}")
